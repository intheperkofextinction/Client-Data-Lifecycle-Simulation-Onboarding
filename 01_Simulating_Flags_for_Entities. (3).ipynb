# %% [markdown]
# ###  Notebook 01 – Simulating Flags for Sender & Receiver Entities
#
# ####  Objective:
# To simulate real-world **risk indicator flags** for **sender and receiver entities** involved in financial transactions. These flags serve as essential features for downstream **risk scoring** and **alert generation** logic.
#
# ####  What We Did:
# - Created a synthetic dataset of sender and receiver entities.
# - Simulated the following key flags:
#
#   - **KYC Status** (e.g., Verified, Unverified, Expired)
#   - **PEP (Politically Exposed Person)**: Higher-risk individuals.
#   - **Watchlist**: Entities listed in global sanctions/watchlists.
#   - **Risk Country**: Entities from high-risk jurisdictions.
#   - **Sanctioned**: Entities already sanctioned (randomly tagged).
#   - **Fraud**: Entities flagged for potential fraud.
#   - **Any Risk Flag**: At least one risk factor is triggered.
#
#   - Generated composite risk flags (`Sender_Any_Risk_Flag`, `Receiver_Any_Risk_Flag`) for quick aggregation of risk.
# - Saved the final dataset for use in later notebooks for scoring, rule logic, and dashboards.
#
# ####  Why This Matters:
# This type of risk flag simulation closely resembles pre-processing workflows in AML/KYC pipelines. It enables:
# - Financial risk scoring systems
# - Real-time or batch alert simulations
# - Regulatory compliance reporting and dashboards
#
#   **Note**: This dataset was simulated and enriched to resemble realistic financial transaction patterns with embedded compliance risk indicators. All transformations are documented step-by-step for transparency.
#
#
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
# Step 1 Define data types to reduce memory usage
dtypes = {
    'From Bank': 'int32',
    'From_Account': 'category',
    'To Bank': 'int32',
    'To_Account': 'category',
    'Amount Received': 'float32',
    'Amount Paid': 'float32',
    'Receiving Currency': 'category',
    'Payment Currency': 'category',
    'Payment Format': 'category',
    'Is Laundering': 'int8'
}

# Step 2  Define datetime columns to parse
parse_dates = ['Timestamp']

# %%
df =pd.read_csv(r"C:\Users\amalm\OneDrive\Desktop\finamcial_data_analysis_lerning\project\Client Data Lifecycle Simulation\merged_data\merged_transactions_with_accounts.csv" ,dtype=dtypes,parse_dates=parse_dates,low_memory=False)
df.head(-10)
# Out:
#                   Timestamp  From Bank From Account  To Bank To Account  \
# 0       2022-09-01 00:08:00         11    8000ECA90       11  8000ECA90
# 1       2022-09-01 00:21:00       3402    80021DAD0     3402  80021DAD0
# 2       2022-09-01 00:00:00         11    8000ECA90     1120  8006AA910
# 3       2022-09-01 00:16:00       3814    8006AD080     3814  8006AD080
# 4       2022-09-01 00:00:00         20    8006AD530       20  8006AD530
# ...                     ...        ...          ...      ...        ...
# 6924034 2022-09-10 23:50:00      70426    819DE8791    71657  81BE73611
# 6924035 2022-09-10 23:30:00         70    10042BA51   170558  81BEAF511
# 6924036 2022-09-10 23:59:00         70    10042BA51   170558  81BEAF511
# 6924037 2022-09-10 23:45:00         70    10042BA51   270308  81BEBEE71
# 6924038 2022-09-10 23:52:00     169671    819940C41   269077  81BF380A1
#
#          Amount Received Receiving Currency   Amount Paid Payment Currency  \
# 0           3.195403e+06          US Dollar  3.195403e+06        US Dollar
# 1           1.858960e+03          US Dollar  1.858960e+03        US Dollar
# 2           5.925710e+05          US Dollar  5.925710e+05        US Dollar
# 3           1.232000e+01          US Dollar  1.232000e+01        US Dollar
# 4           2.941560e+03          US Dollar  2.941560e+03        US Dollar
# ...                  ...                ...           ...              ...
# 6924034     2.924000e-02            Bitcoin  2.924000e-02          Bitcoin
# 6924035     3.661940e-01            Bitcoin  3.661940e-01          Bitcoin
# 6924036     5.755200e-02            Bitcoin  5.755200e-02          Bitcoin
# 6924037     1.623860e-01            Bitcoin  1.623860e-01          Bitcoin
# 6924038     1.155100e-02            Bitcoin  1.155100e-02          Bitcoin
#
#         Payment Format  ...             From Bank Name Bank ID  \
# 0         Reinvestment  ...    Savings Bank of Madison      11
# 1         Reinvestment  ...  National Bank of New York    3402
# 2               Cheque  ...    Savings Bank of Madison      11
# 3         Reinvestment  ...               Sappo Thrift    3814
# 4         Reinvestment  ...      First Bank of Danbury      20
# ...                ...  ...                        ...     ...
# 6924034        Bitcoin  ...            Crytpo Bank #59   70426
# 6924035        Bitcoin  ...             Willows Thrift      70
# 6924036        Bitcoin  ...             Willows Thrift      70
# 6924037        Bitcoin  ...             Willows Thrift      70
# 6924038        Bitcoin  ...            Crytpo Bank #50  169671
#
#          Account Number Sender Entity ID      Sender Entity Name  \
# 0             8000ECA90        80006E250           Individual #1
# 1             80021DAD0        80154AF70  Sole Proprietorship #1
# 2             8000ECA90        80006E250           Individual #1
# 3             8006AD080        801415540          Partnership #2
# 4             8006AD530        800CA6070          Corporation #1
# ...                 ...              ...                     ...
# 6924034       819DE8791        8015B10D0        Partnership #953
# 6924035       10042BA51        8015B10D0        Partnership #953
# 6924036       10042BA51        8015B10D0        Partnership #953
# 6924037       10042BA51        8015B10D0        Partnership #953
# 6924038       819940C41        8015B10D0        Partnership #953
#
#                       To Bank Name Bank ID_Receiver  Account Number_Receiver  \
# 0          Savings Bank of Madison               11                8000ECA90
# 1        National Bank of New York             3402                80021DAD0
# 2          First Bank of the South             1120                8006AA910
# 3                     Sappo Thrift             3814                8006AD080
# 4            First Bank of Danbury               20                8006AD530
# ...                            ...              ...                      ...
# 6924034            Crytpo Bank #97            71657                81BE73611
# 6924035            Crytpo Bank #41           170558                81BEAF511
# 6924036            Crytpo Bank #41           170558                81BEAF511
# 6924037            Crytpo Bank #16           270308                81BEBEE71
# 6924038            Crytpo Bank #11           269077                81BF380A1
#
#         Receiver Entity ID    Receiver Entity Name
# 0                80006E250           Individual #1
# 1                80154AF70  Sole Proprietorship #1
# 2                801537F30          Partnership #1
# 3                801415540          Partnership #2
# 4                800CA6070          Corporation #1
# ...                    ...                     ...
# 6924034          8006D12E0      Partnership #50307
# 6924035          8000FBB80      Corporation #49952
# 6924036          8000FBB80      Corporation #49952
# 6924037          8015B10D0        Partnership #953
# 6924038          8000FBB80      Corporation #49952
#
# [6924039 rows x 21 columns]

# %%
entities = pd.concat ([
    df[['Sender Entity ID', 'Sender Entity Name']].rename(columns={
        'Sender Entity ID': 'Entity ID', 'Sender Entity Name': 'Entity Name'}),
    df[['Receiver Entity ID', 'Receiver Entity Name']].rename(columns={
        'Receiver Entity ID': 'Entity ID', 'Receiver Entity Name': 'Entity Name'})
]).drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ##  Generating Risk Flags from Entity Attributes
#
# We simulate whether an entity is a PEP, is on a Watchlist, or is from a Risk Country using existing columns:
#
# - If the entity's `type` is in a pre-defined list → PEP flag = 1.
# - If the entity's `name` matches names in a known watchlist → Watchlist flag = 1.
# - If the entity is from a known high-risk country → Risk Country flag = 1.
#
# These flags are useful for identifying red flags in KYC (Know Your Customer) processes.

# %%
# Simulate KYC attributes
np.random.seed(42)
entities['PEP_Flag'] = np.random.choice([0, 1], size=len(entities), p=[0.95, 0.05])
entities['Watchlist_Flag'] = np.random.choice([0, 1], size=len(entities), p=[0.97, 0.03])
entities['Risk_Country_Flag'] = np.random.choice([0, 1], size=len(entities), p=[0.90, 0.10])
entities['KYC_Status'] = np.where(entities['Watchlist_Flag'] == 1, 'Fail', 'Pass')

# %%
entities.head()
# Out:
#    Entity ID             Entity Name  PEP_Flag  Watchlist_Flag  \
# 0  80006E250           Individual #1         0               0
# 1  80154AF70  Sole Proprietorship #1         1               0
# 2  801415540          Partnership #2         0               0
# 3  800CA6070          Corporation #1         0               0
# 4  8011BBB00          Partnership #3         0               1
#
#    Risk_Country_Flag KYC_Status
# 0                  0       Pass
# 1                  1       Pass
# 2                  0       Pass
# 3                  0       Pass
# 4                  0       Fail

# %%
# Merge with sender
df = df.merge(
    entities.rename(columns=lambda x: f"Sender_{x}" if x not in ['Entity ID'] else 'Sender Entity ID'),
    on='Sender Entity ID',
    how='left'
)

# Merge with receiver
df = df.merge(
    entities.rename(columns=lambda x: f"Receiver_{x}" if x not in ['Entity ID'] else 'Receiver Entity ID'),
    on='Receiver Entity ID',
    how='left'
)

# %%
df.head(10)
# Out:
#             Timestamp  From Bank From Account  To Bank To Account  \
# 0 2022-09-01 00:08:00         11    8000ECA90       11  8000ECA90
# 1 2022-09-01 00:21:00       3402    80021DAD0     3402  80021DAD0
# 2 2022-09-01 00:00:00         11    8000ECA90     1120  8006AA910
# 3 2022-09-01 00:16:00       3814    8006AD080     3814  8006AD080
# 4 2022-09-01 00:00:00         20    8006AD530       20  8006AD530
# 5 2022-09-01 00:24:00         12    8006ADD30       12  8006ADD30
# 6 2022-09-01 00:17:00         11    800059120     1217  8006AD4E0
# 7 2022-09-01 00:07:00         11    8000ECA90       11  8000ECA90
# 8 2022-09-01 00:28:00       1120    8006AA910   243166  81470DCF0
# 9 2022-09-01 00:22:00       1217    8006AD4E0     1217  8006AD4E0
#
#    Amount Received Receiving Currency   Amount Paid Payment Currency  \
# 0     3.195403e+06          US Dollar  3.195403e+06        US Dollar
# 1     1.858960e+03          US Dollar  1.858960e+03        US Dollar
# 2     5.925710e+05          US Dollar  5.925710e+05        US Dollar
# 3     1.232000e+01          US Dollar  1.232000e+01        US Dollar
# 4     2.941560e+03          US Dollar  2.941560e+03        US Dollar
# 5     6.473620e+03          US Dollar  6.473620e+03        US Dollar
# 6     6.056200e+04          US Dollar  6.056200e+04        US Dollar
# 7     2.297000e+01          US Dollar  2.297000e+01        US Dollar
# 8     4.353000e+01          US Dollar  4.353000e+01        US Dollar
# 9     5.040000e+00          US Dollar  5.040000e+00        US Dollar
#
#   Payment Format  ...      Sender_Entity Name Sender_PEP_Flag  \
# 0   Reinvestment  ...           Individual #1               0
# 1   Reinvestment  ...  Sole Proprietorship #1               1
# 2         Cheque  ...           Individual #1               0
# 3   Reinvestment  ...          Partnership #2               0
# 4   Reinvestment  ...          Corporation #1               0
# 5   Reinvestment  ...          Partnership #3               0
# 6            ACH  ...  Sole Proprietorship #2               0
# 7   Reinvestment  ...           Individual #1               0
# 8    Credit Card  ...          Partnership #1               0
# 9   Reinvestment  ...          Corporation #2               0
#
#    Sender_Watchlist_Flag Sender_Risk_Country_Flag Sender_KYC_Status  \
# 0                      0                        0              Pass
# 1                      0                        1              Pass
# 2                      0                        0              Pass
# 3                      0                        0              Pass
# 4                      0                        0              Pass
# 5                      1                        0              Fail
# 6                      0                        1              Pass
# 7                      0                        0              Pass
# 8                      0                        1              Pass
# 9                      0                        0              Pass
#
#      Receiver_Entity Name Receiver_PEP_Flag  Receiver_Watchlist_Flag  \
# 0           Individual #1                 0                        0
# 1  Sole Proprietorship #1                 1                        0
# 2          Partnership #1                 0                        0
# 3          Partnership #2                 0                        0
# 4          Corporation #1                 0                        0
# 5          Partnership #3                 0                        1
# 6          Corporation #2                 0                        0
# 7           Individual #1                 0                        0
# 8          Partnership #4                 1                        0
# 9          Corporation #2                 0                        0
#
#   Receiver_Risk_Country_Flag Receiver_KYC_Status
# 0                          0                Pass
# 1                          1                Pass
# 2                          1                Pass
# 3                          0                Pass
# 4                          0                Pass
# 5                          0                Fail
# 6                          0                Pass
# 7                          0                Pass
# 8                          0                Pass
# 9                          0                Pass
#
# [10 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6924049 entries, 0 to 6924048
# Data columns (total 31 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Timestamp                   datetime64[ns]
#  1   From Bank                   int32
#  2   From Account                object
#  3   To Bank                     int32
#  4   To Account                  object
#  5   Amount Received             float32
#  6   Receiving Currency          category
#  7   Amount Paid                 float32
#  8   Payment Currency            category
#  9   Payment Format              category
#  10  Is Laundering               int8
#  11  From Bank Name              object
#  12  Bank ID                     int64
#  13  Account Number              object
#  14  Sender Entity ID            object
#  15  Sender Entity Name          object
#  16  To Bank Name                object
#  17  Bank ID_Receiver            int64
#  18  Account Number_Receiver     object
#  19  Receiver Entity ID          object
#  20  Receiver Entity Name        object
#  21  Sender_Entity Name          object
#  22  Sender_PEP_Flag             int32
#  23  Sender_Watchlist_Flag       int32
#  24  Sender_Risk_Country_Flag    int32
#  25  Sender_KYC_Status           object
#  26  Receiver_Entity Name        object
#  27  Receiver_PEP_Flag           int32
#  28  Receiver_Watchlist_Flag     int32
#  29  Receiver_Risk_Country_Flag  int32
#  30  Receiver_KYC_Status         object
# dtypes: category(3), datetime64[ns](1), float32(2), int32(8), int64(2), int8(1), object(14)
# memory usage: 1.2+ GB

# %% [markdown]
# ##  Simulating Fraud and Sanctioned Columns
#
# We introduce randomness to simulate:
# - **Fraud Flag**: Randomly assigned to ~5% of rows to simulate real-world fraud prevalence.
# - **Sanctioned Flag**: Assigned to ~2% of rows, representing entities flagged by regulatory bodies.
#
# These probabilities reflect realistic compliance data distributions and help in building synthetic datasets for supervised learning or dashboard monitoring.

# %%
# Simulate Fraud Flags: 5% chance of being flagged
df['Sender_Fraud_Flag'] = np.random.choice([0, 1], size=len(df), p=[0.95, 0.05])
df['Receiver_Fraud_Flag'] = np.random.choice([0, 1], size=len(df), p=[0.95, 0.05])

# Simulate Sanctioned Flags: 2% chance
df['Sender_Sanctioned_Flag'] = np.random.choice([0, 1], size=len(df), p=[0.98, 0.02])
df['Receiver_Sanctioned_Flag'] = np.random.choice([0, 1], size=len(df), p=[0.98, 0.02])

# %% [markdown]
# ##  Aggregating Risk Flags
#
# We create a single `any_flagged` column that indicates whether an entity is flagged for **any** of the risk factors (PEP, Watchlist, Risk Country, Fraud, or Sanctioned).
#
# This simplifies filtering and visualization in downstream applications (e.g., dashboards, machine learning).

# %%
# Does entity raise any flag 
df['Sender_Any_Risk_Flag'] = (
    df['Sender_PEP_Flag'] | 
    df['Sender_Watchlist_Flag'] | 
    df['Sender_Risk_Country_Flag'] |
    df['Sender_Fraud_Flag'] |
    df['Sender_Sanctioned_Flag']
)
df['Receiver_Any_Risk_Flag'] = (
    df['Receiver_PEP_Flag'] | 
    df['Receiver_Watchlist_Flag'] | 
    df['Receiver_Risk_Country_Flag'] |
    df['Receiver_Fraud_Flag']|
    df['Receiver_Sanctioned_Flag']
    
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6924049 entries, 0 to 6924048
# Data columns (total 37 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Timestamp                   datetime64[ns]
#  1   From Bank                   int32
#  2   From Account                object
#  3   To Bank                     int32
#  4   To Account                  object
#  5   Amount Received             float32
#  6   Receiving Currency          category
#  7   Amount Paid                 float32
#  8   Payment Currency            category
#  9   Payment Format              category
#  10  Is Laundering               int8
#  11  From Bank Name              object
#  12  Bank ID                     int64
#  13  Account Number              object
#  14  Sender Entity ID            object
#  15  Sender Entity Name          object
#  16  To Bank Name                object
#  17  Bank ID_Receiver            int64
#  18  Account Number_Receiver     object
#  19  Receiver Entity ID          object
#  20  Receiver Entity Name        object
#  21  Sender_Entity Name          object
#  22  Sender_PEP_Flag             int32
#  23  Sender_Watchlist_Flag       int32
#  24  Sender_Risk_Country_Flag    int32
#  25  Sender_KYC_Status           object
#  26  Receiver_Entity Name        object
#  27  Receiver_PEP_Flag           int32
#  28  Receiver_Watchlist_Flag     int32
#  29  Receiver_Risk_Country_Flag  int32
#  30  Receiver_KYC_Status         object
#  31  Sender_Fraud_Flag           int32
#  32  Receiver_Fraud_Flag         int32
#  33  Sender_Sanctioned_Flag      int32
#  34  Receiver_Sanctioned_Flag    int32
#  35  Sender_Any_Risk_Flag        int32
#  36  Receiver_Any_Risk_Flag      int32
# dtypes: category(3), datetime64[ns](1), float32(2), int32(14), int64(2), int8(1), object(14)
# memory usage: 1.3+ GB

# %% [markdown]
# ##  Saving Transformed Data
#
# The final dataframe is saved as a CSV file for use in subsequent analysis notebooks. This modular design ensures reusability and clean data flow across the project.

# %%
df.to_csv(r"C:\Users\amalm\OneDrive\Desktop\finamcial_data_analysis_lerning\project\Client Data Lifecycle Simulation\merged_data\flagged_data.csv", index =False)

# %% [markdown]
# ##  Summary
#
# - Created 5 binary risk flags using a combination of logic and randomness.
# - Introduced synthetic but realistic indicators used in financial compliance workflows.
# - Saved the enriched dataset for use in dashboards, fraud detection models, or reporting pipelines.
#
# This notebook lays the foundation for visualizing and analyzing entity-level risk in a structured and scalable way.
